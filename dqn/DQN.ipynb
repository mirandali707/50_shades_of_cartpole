# %% [markdown]
# # Deep Q Network
# Like Q-learning, except with two Big Ideas:
# 1. experience replay: store all prior experiences in a replay buffer; in each SGD step, randomly sample an experience tuple to update the network weights.
# 2. fixed Q-targets: maintain a separate target network that uses a different set of weights than the ones being updated (which are used to decide waht actons to take); only update the target network every n iters (e.g. 1000).
#
# ![](DQN.png)

# %%
import sys
sys.path.append('..')
from utils.plotting import plot_trial_results
from agent import init_agent, reset_agent, get_action, update, model_name, save_trained_agent, init_trained_agent
from train import train_loop

all_trial_results = train_loop(init_agent, reset_agent, get_action, update, model_name, save_trained_agent)
mean_curve = all_trial_results.mean(axis=0)
std_curve = all_trial_results.std(axis=0)
plot_trial_results(model_name, mean_curve, std_curve)
# Out:
# /Users/miranda/miniconda3/envs/nmm_finalproject/lib/python3.12/site-packages/gymnasium/envs/registration.py:729: UserWarning: WARN: The environment is being initialised with render_mode='none' that is not in the possible render_modes (['human', 'rgb_array']).
#   logger.warn(
# repeat 0: 100%|██████████| 1000/1000 [03:20<00:00,  5.00it/s, steps=500]
# avg of last 5 trials: 500
# repeat 1: 100%|██████████| 1000/1000 [03:31<00:00,  4.72it/s, steps=330]
# avg of last 5 trials: 337
# repeat 2: 100%|██████████| 1000/1000 [04:18<00:00,  3.86it/s, steps=500]
# avg of last 5 trials: 500
# repeat 3: 100%|██████████| 1000/1000 [04:17<00:00,  3.88it/s, steps=11]
# avg of last 5 trials: 8
# repeat 4: 100%|██████████| 1000/1000 [05:27<00:00,  3.06it/s, steps=151]
# avg of last 5 trials: 159
# repeat 5: 100%|██████████| 1000/1000 [05:31<00:00,  3.01it/s, steps=500]
# avg of last 5 trials: 500
# repeat 6: 100%|██████████| 1000/1000 [05:10<00:00,  3.22it/s, steps=500]
# avg of last 5 trials: 500
# repeat 7: 100%|██████████| 1000/1000 [02:58<00:00,  5.59it/s, steps=209]
# avg of last 5 trials: 211
# repeat 8: 100%|██████████| 1000/1000 [02:49<00:00,  5.91it/s, steps=156]
# avg of last 5 trials: 249
# repeat 9: 100%|██████████| 1000/1000 [04:13<00:00,  3.95it/s, steps=500]
# avg of last 5 trials: 500
# Final trial (#1000) steps alive across 10 reps: 346.40 ± 171.90

# %%
# eval
from eval import eval_loop
eval_results = eval_loop(init_trained_agent, reset_agent, get_action, model_name)
# Out:
# /Users/miranda/miniconda3/envs/nmm_finalproject/lib/python3.12/site-packages/gymnasium/envs/registration.py:729: UserWarning: WARN: The environment is being initialised with render_mode='none' that is not in the possible render_modes (['human', 'rgb_array']).
#   logger.warn(
# repeat 0: 100%|██████████| 100/100 [00:22<00:00,  4.52it/s, steps=500]
# repeat 1: 100%|██████████| 100/100 [00:20<00:00,  4.79it/s, steps=500]
# repeat 2: 100%|██████████| 100/100 [00:20<00:00,  4.77it/s, steps=500]
# repeat 3: 100%|██████████| 100/100 [00:20<00:00,  4.76it/s, steps=500]
# repeat 4: 100%|██████████| 100/100 [00:20<00:00,  4.78it/s, steps=500]
# repeat 5: 100%|██████████| 100/100 [00:21<00:00,  4.56it/s, steps=500]
# repeat 6: 100%|██████████| 100/100 [00:22<00:00,  4.48it/s, steps=500]
# repeat 7: 100%|██████████| 100/100 [00:21<00:00,  4.65it/s, steps=500]
# repeat 8: 100%|██████████| 100/100 [00:21<00:00,  4.60it/s, steps=500]
# repeat 9: 100%|██████████| 100/100 [00:21<00:00,  4.55it/s, steps=500]
# steps alive across 10 reps, 100 per rep: 499.52 ± 10.04

# %%
import sys
sys.path.append('..')
from agent import init_agent, reset_agent, get_action, update, model_name, save_trained_agent, init_trained_agent
from utils.record_video import record_video

record_video(
    init_trained_agent,
    reset_agent,
    get_action,
    model_name
)
# Out:
# /Users/miranda/miniconda3/envs/nmm_finalproject/lib/python3.12/site-packages/gymnasium/wrappers/rendering.py:292: UserWarning: WARN: Overwriting existing videos at /Users/miranda/code/mit/spring26/nmm/finalproject/dqn folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# recorded 500-step rollout to ./DQN-episode-0.mp4
