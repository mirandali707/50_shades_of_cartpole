# %% [markdown]
# # Basic random search
# Here we implement the Basic Random Search algorithm from [Simple random search provides a competitive approach to reinforcement learning](https://arxiv.org/pdf/1803.07055).
# For each "iteration" of the algorithm we perturb our weight vector theta symmetrically in N random directions (+/- direction) and rollout each of those weight vectors. After collecting the reward from those trajectories, we take the differences between the + and - rewards in each direction, multiply them by the direction they were derived from, and average that (scaled by alpha). Basically, we want to nudge our theta in the directions which did better, scaled by how much better they did.
#
# Here's the pseudocode:
# ![](BRS.png)

# %%
import sys
sys.path.append('..')
from agent import init_agent, reset_agent, get_action, update, model_name, save_trained_agent, init_trained_agent

from train import train_loop
from utils.plotting import plot_trial_results

# if training:
all_trial_results = train_loop(init_agent, reset_agent, get_action, update, model_name, save_trained_agent)
mean_curve = all_trial_results.mean(axis=0)
std_curve = all_trial_results.std(axis=0)
plot_trial_results(model_name, mean_curve, std_curve)
# Out:
# /Users/miranda/miniconda3/envs/nmm_finalproject/lib/python3.12/site-packages/gymnasium/envs/registration.py:729: UserWarning: WARN: The environment is being initialised with render_mode='none' that is not in the possible render_modes (['human', 'rgb_array']).
#   logger.warn(
# repeat 0: 100%|██████████| 1000/1000 [00:29<00:00, 34.41it/s, steps=500, best=500]
# repeat 1: 100%|██████████| 1000/1000 [00:02<00:00, 388.18it/s, steps=9, best=500]
# repeat 2: 100%|██████████| 1000/1000 [00:03<00:00, 301.92it/s, steps=10, best=500]
# repeat 3: 100%|██████████| 1000/1000 [00:29<00:00, 33.68it/s, steps=500, best=500]
# repeat 4: 100%|██████████| 1000/1000 [00:24<00:00, 40.57it/s, steps=8, best=500]
# repeat 5: 100%|██████████| 1000/1000 [00:04<00:00, 215.58it/s, steps=33, best=500]
# repeat 6: 100%|██████████| 1000/1000 [00:28<00:00, 34.53it/s, steps=500, best=500]
# repeat 7: 100%|██████████| 1000/1000 [00:28<00:00, 34.75it/s, steps=500, best=500]
# repeat 8: 100%|██████████| 1000/1000 [00:28<00:00, 34.87it/s, steps=500, best=500]
# repeat 9: 100%|██████████| 1000/1000 [00:29<00:00, 34.22it/s, steps=500, best=500]

# %%
# eval
from eval import eval_loop
eval_results = eval_loop(init_trained_agent, reset_agent, get_action, model_name)
# Out:
# /Users/miranda/miniconda3/envs/nmm_finalproject/lib/python3.12/site-packages/gymnasium/envs/registration.py:729: UserWarning: WARN: The environment is being initialised with render_mode='none' that is not in the possible render_modes (['human', 'rgb_array']).
#   logger.warn(
# repeat 0: 100%|██████████| 100/100 [00:02<00:00, 34.47it/s, steps=500]
# repeat 1: 100%|██████████| 100/100 [00:03<00:00, 33.30it/s, steps=500]
# repeat 2: 100%|██████████| 100/100 [00:02<00:00, 34.28it/s, steps=500]
# repeat 3: 100%|██████████| 100/100 [00:02<00:00, 34.42it/s, steps=500]
# repeat 4: 100%|██████████| 100/100 [00:02<00:00, 34.44it/s, steps=500]
# repeat 5: 100%|██████████| 100/100 [00:02<00:00, 33.91it/s, steps=500]
# repeat 6: 100%|██████████| 100/100 [00:02<00:00, 33.99it/s, steps=500]
# repeat 7: 100%|██████████| 100/100 [00:02<00:00, 33.78it/s, steps=500]
# repeat 8: 100%|██████████| 100/100 [00:02<00:00, 34.52it/s, steps=500]
# repeat 9: 100%|██████████| 100/100 [00:02<00:00, 35.72it/s, steps=500]
# steps alive across 10 reps, 100 per rep: 499.94 ± 0.85

# %%
import sys
sys.path.append('..')
from agent import init_agent, reset_agent, get_action, update, model_name, save_trained_agent, init_trained_agent
from utils.record_video import record_video

record_video(
    init_trained_agent,
    reset_agent,
    get_action,
    model_name
)
# Out:
# /Users/miranda/miniconda3/envs/nmm_finalproject/lib/python3.12/site-packages/gymnasium/wrappers/rendering.py:292: UserWarning: WARN: Overwriting existing videos at /Users/miranda/code/mit/spring26/nmm/finalproject/basic_random_search/videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# recorded 500-step rollout to videos/Basic Random Search-episode-0.mp4
